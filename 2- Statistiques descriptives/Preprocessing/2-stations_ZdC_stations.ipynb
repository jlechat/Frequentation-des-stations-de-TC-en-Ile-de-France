# %% [markdown]
# # Vérification de l'intégrité de la clé ZdC et transformation de la base des stations
#
# *remarque* : la base des stations a déjà été jointe avec les données de l'Insee précédemment.
#
# Ce NoteBook a pour but de vérifier l'intégriter de la clé ZdC, seule code disponible pour faire une jointure avec les données de validation d'Île De France Mobilités (_IDFM_).
#
# Il s'agit donc de vérifier que l'on peut faire la jointure sans problème (i.e. sans redoncance), puis de modifier la base si besoin.
#
# ## Packages et importation des données

# %%
import pandas as pd
from _importation_donnees import donnees_validation_23
from _pre_proces_Insee_IDFM import data_INSEE_stations

# %%
stations_RER=data_INSEE_stations()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/mamba/share/proj failed

# %% [markdown]
# ## Vérification de l'intégrité de la clé *ZdC* sur les données de *RER*

# %%
print(stations_RER['nom_ZdC'].nunique())
print(stations_RER['id_ref_ZdC'].nunique())
# Out:
# 234
# 234

# %% [markdown]
# *A priori* il n'y a pas d'écart. Il reste à vérifier qu'il s'agit bien d'une petite erreur et non pas de mauvais matching.
#
# ### ZdC avec plusieurs noms de stations différents

# %%
stations_RER
# Out:
#                                   Geo Point  \
# 0      48.93230541513496, 2.475674370833511
# 1     48.955402243597064, 2.093521901580611
# 2      49.03646397979169, 2.079534939997373
# 3      48.56494949473517, 2.594551816007612
# 4    48.861822271863645, 2.3470126872387564
# ..                                      ...
# 249  48.962709512366416, 2.5126446278196126
# 250     49.00468746087186, 2.57058948552452
# 251   49.00975645120457, 2.5612326952251054
# 252   48.97342490628139, 2.5143602855334923
# 253  48.869950134005364, 2.7822267234490363
#
#                                              Geo Shape  gares_id  \
# 0    {"coordinates": [2.475674370833511, 48.9323054...        77
# 1    {"coordinates": [2.093521901580611, 48.9554022...         4
# 2    {"coordinates": [2.079534939997373, 49.0364639...       129
# 3    {"coordinates": [2.594551816007612, 48.5649494...       135
# 4    {"coordinates": [2.347012687238756, 48.8618222...       163
# ..                                                 ...       ...
# 249  {"coordinates": [2.512644627819613, 48.9627095...       905
# 250  {"coordinates": [2.57058948552452, 49.00468746...       744
# 251  {"coordinates": [2.561232695225105, 49.0097564...       743
# 252  {"coordinates": [2.514360285533492, 48.9734249...       621
# 253  {"coordinates": [2.782226723449036, 48.8699501...       182
#
#                              nom_long nom_so_gar nom_su_gar  id_ref_ZdC  \
# 0                     Le Blanc-Mesnil        NaN        NaN       72648
# 1               Achères-Grand-Cormier        NaN        NaN       65190
# 2                    Cergy-Préfecture        NaN        NaN       66696
# 3                              Cesson        NaN        NaN       62176
# 4                 Châtelet-Les Halles        NaN        NaN      474151
# ..                                ...        ...        ...         ...
# 249                        Villepinte        NaN        NaN       73547
# 250  Aéroport Charles De Gaulle 2-TGV        NaN        NaN       73699
# 251      Aéroport Charles De Gaulle 1        NaN        NaN       73596
# 252              Parc des Expositions        NaN        NaN       73568
# 253            Marne-la-Vallée-Chessy        NaN        NaN       68385
#
#                              nom_ZdC  id_ref_ZdA  \
# 0                    Le Blanc-Mesnil       46163
# 1              Achères Grand Cormier       47915
# 2                   Cergy Préfecture       44559
# 3                             Cesson       42516
# 4                Châtelet les Halles       45102
# ..                               ...         ...
# 249                       Villepinte       58793
# 250  Aéroport CDG - Terminal 2 (TGV)      473364
# 251      Aéroport CDG 1 (Terminal 3)      462398
# 252             Parc des Expositions       47878
# 253           Marne-la-Vallée Chessy       43239
#
#                                        nom_ZdA  ... ind_25_39 ind_40_54  \
# 0                              Le Blanc-Mesnil  ...    1406.0    1374.0
# 1                        Achères Grand Cormier  ...      17.4      20.6
# 2                             Cergy Préfecture  ...    1789.1    1143.0
# 3                                       Cesson  ...     461.0     544.0
# 4                          Châtelet les Halles  ...    8501.5    6004.0
# ..                                         ...  ...       ...       ...
# 249                                 Villepinte  ...       0.0       0.0
# 250  Aéroport Charles de Gaulle 2 (Terminal 2)  ...       0.0       0.0
# 251          Aéroport CDG 1 (Terminal 3) - RER  ...       0.0       0.0
# 252                       Parc des Expositions  ...       0.0       0.0
# 253                     Marne-la-Vallée Chessy  ...       0.0       0.0
#
#     ind_55_64 ind_65_79 ind_80p ind_inc pre_IDF select expt
# 0       758.0     603.0   210.0    18.0     1.0    1.0  1.0          NaN
# 1         8.0       0.7     0.8     0.0     1.0    1.0  1.0          NaN
# 2       559.1     409.0   107.0    26.0     1.0    1.0  1.0          NaN
# 3       324.0     300.0   192.0     3.0     1.0    1.0  1.0          NaN
# 4      2991.0    2856.0   863.0    20.0     1.0    1.0  1.0          NaN
# ..        ...       ...     ...     ...     ...    ...  ...          ...
# 249       0.0       0.0     0.0     NaN     NaN    NaN  NaN  664313.9648
# 250       0.0       0.0     0.0     NaN     NaN    NaN  NaN  668582.2523
# 251       0.0       0.0     0.0     NaN     NaN    NaN  NaN  667900.8037
# 252       0.0       0.0     0.0     NaN     NaN    NaN  NaN  664446.9190
# 253       0.0       0.0     0.0     NaN     NaN    NaN  NaN  684025.2740
#
# [244 rows x 64 columns]

# %%
stations_RER[stations_RER['nom_long']=='Cesson']
# Out:
#                               Geo Point  \
# 3  48.56494949473517, 2.594551816007612
#
#                                            Geo Shape  gares_id nom_long  \
# 3  {"coordinates": [2.594551816007612, 48.5649494...       135   Cesson
#
#   nom_so_gar nom_su_gar  id_ref_ZdC nom_ZdC  id_ref_ZdA nom_ZdA  ...  \
# 3        NaN        NaN       62176  Cesson       42516  Cesson  ...
#
#   ind_25_39 ind_40_54 ind_55_64 ind_65_79 ind_80p ind_inc pre_IDF select expt  \
# 3     461.0     544.0     324.0     300.0   192.0     3.0     1.0    1.0  1.0
#
#
# 3 NaN
#
# [1 rows x 64 columns]

# %%
#On se restreint aux colonnes lda et LIBELLE_ARRET
sub_data = stations_RER[['id_ref_ZdC', 'nom_ZdC']]
#Suppression des doublons
unique_stations = sub_data.drop_duplicates()
#On aggrège et on filre pour avoir les stations qui ont structement plus de 1 LDA
multi_zdc_stations = unique_stations.groupby('nom_ZdC').filter(lambda x: x['id_ref_ZdC'].nunique() > 1)
#On trie par ordre alphabétique pour faciliter la lecture
multi_zdc_stations.sort_values(by='nom_ZdC')
# Out:
# Empty DataFrame
# Columns: [id_ref_ZdC, nom_ZdC]
# Index: []

# %% [markdown]
# Pas de problème dans ce sens là.

# %% [markdown]
# ### Noms de stations avec plusieurs ZdC

# %%
#On se restreint aux colonnes lda et LIBELLE_ARRET
sub_data = stations_RER[['id_ref_ZdC', 'nom_ZdC']]
#Suppression des doublons
unique_stations = sub_data.drop_duplicates()
#On aggrège et on filre pour avoir les stations qui ont structement plus de 1 LDA
multi_zdc_stations = unique_stations.groupby('id_ref_ZdC').filter(lambda x: x['nom_ZdC'].nunique() > 1)
#On trie par ordre alphabétique pour faciliter la lecture
multi_zdc_stations.sort_values(by='id_ref_ZdC')
# Out:
# Empty DataFrame
# Columns: [id_ref_ZdC, nom_ZdC]
# Index: []

# %% [markdown]
# ## Suppression des redondance des stations

# %% [markdown]
# La base que nous avions déjà préparées pour les stations de RER est donc quasi-opérationnelle. Il nous reste maintenant a éliminer les redondances car les stations avec correspondance sont comptées autant de fois qu'il y a de ligne (cela posera problème si l'on fait une jointure).

# %%
# Étape 1: Trouver les valeurs de 'id_ref_ZdC' qui apparaissent plus d'une fois.
duplicate_id_ref_ZdC = stations_RER['id_ref_ZdC'].value_counts()
duplicate_id_ref_ZdC = duplicate_id_ref_ZdC[duplicate_id_ref_ZdC > 1].index

# Étape 2: Filtrer le DataFrame pour afficher seulement les lignes avec les valeurs répétées de 'id_ref_ZdC'
stations_RER_duplicates = stations_RER[stations_RER['id_ref_ZdC'].isin(duplicate_id_ref_ZdC)]
stations_RER_duplicates
# Out:
#                                   Geo Point  \
# 4    48.861822271863645, 2.3470126872387564
# 5    48.861822271863645, 2.3470126872387564
# 6    48.861822271863645, 2.3470126872387564
# 14   48.725997091123524, 2.2583229936112406
# 15     48.72509804026411, 2.259946049525821
# 19     48.88077520385858, 2.358732959087859
# 20    48.881759488218286, 2.357570193470876
# 21    48.881759488218286, 2.357570193470876
# 47      48.8437725759169, 2.373916469806498
# 48    48.844139348918475, 2.373259976710645
# 58    48.85409607732852, 2.4886964657999346
# 59     48.85426899270086, 2.489167460948014
# 66      48.85353289978531, 2.34528833219743
# 67   48.852118881696434, 2.3440211520552796
# 168  48.734888146410114, 2.2740024044842473
# 169  48.734888146410114, 2.2740024044842473
# 176   48.689764621447345, 2.382846099452605
# 177   48.689567256029264, 2.383833358799738
#
#                                              Geo Shape  gares_id  \
# 4    {"coordinates": [2.347012687238756, 48.8618222...       163
# 5    {"coordinates": [2.347012687238756, 48.8618222...       164
# 6    {"coordinates": [2.347012687238756, 48.8618222...       170
# 14   {"coordinates": [2.258322993611241, 48.7259970...       522
# 15   {"coordinates": [2.259946049525821, 48.7250980...       520
# 19   {"coordinates": [2.358732959087859, 48.8807752...       490
# 20   {"coordinates": [2.357570193470876, 48.8817594...       309
# 21   {"coordinates": [2.357570193470876, 48.8817594...       310
# 47   {"coordinates": [2.373916469806498, 48.8437725...       307
# 48   {"coordinates": [2.373259976710645, 48.8441393...       306
# 58   {"coordinates": [2.488696465799935, 48.8540960...       869
# 59   {"coordinates": [2.489167460948014, 48.8542689...       868
# 66   {"coordinates": [2.34528833219743, 48.85353289...       828
# 67   {"coordinates": [2.34402115205528, 48.85211888...       827
# 168  {"coordinates": [2.274002404484247, 48.7348881...       524
# 169  {"coordinates": [2.274002404484247, 48.7348881...       523
# 176  {"coordinates": [2.382846099452605, 48.6897646...       385
# 177  {"coordinates": [2.383833358799738, 48.6895672...       387
#
#                 nom_long  nom_so_gar nom_su_gar  id_ref_ZdC  \
# 4    Châtelet-Les Halles         NaN        NaN      474151
# 5    Châtelet-Les Halles         NaN        NaN      474151
# 6    Châtelet-Les Halles         NaN        NaN      474151
# 14       Massy-Palaiseau         NaN        NaN       63244
# 15       Massy-Palaiseau         NaN        NaN       63244
# 19               Magenta         NaN        NaN      478733
# 20          Gare du Nord         NaN        NaN      478733
# 21          Gare du Nord         NaN        NaN      478733
# 47          Gare de Lyon         NaN        NaN       73626
# 48          Gare de Lyon         NaN        NaN       73626
# 58       Val de Fontenay         NaN        NaN       71718
# 59       Val de Fontenay         NaN        NaN       71718
# 66          Saint-Michel  Notre-Dame        NaN       73620
# 67          Saint-Michel  Notre-Dame        NaN       73620
# 168      Massy-Verrières         NaN        NaN       63320
# 169      Massy-Verrières         NaN        NaN       63320
# 176               Juvisy         NaN        NaN      478505
# 177               Juvisy         NaN        NaN      478505
#
#                      nom_ZdC  id_ref_ZdA                  nom_ZdA  ...  \
# 4        Châtelet les Halles       45102      Châtelet les Halles  ...
# 5        Châtelet les Halles       45102      Châtelet les Halles  ...
# 6        Châtelet les Halles       45102      Châtelet les Halles  ...
# 14         Massy - Palaiseau       58774        Massy - Palaiseau  ...
# 15         Massy - Palaiseau       58774        Massy - Palaiseau  ...
# 19              Gare du Nord       58572                  Magenta  ...
# 20              Gare du Nord       58572                  Magenta  ...
# 21              Gare du Nord       58572                  Magenta  ...
# 47              Gare de Lyon      470195             Gare de Lyon  ...
# 48              Gare de Lyon      470195             Gare de Lyon  ...
# 58           Val de Fontenay       47900          Val de Fontenay  ...
# 59           Val de Fontenay       47900          Val de Fontenay  ...
# 66   Saint-Michel Notre-Dame       44877  Saint-Michel Notre-Dame  ...
# 67   Saint-Michel Notre-Dame       44877  Saint-Michel Notre-Dame  ...
# 168        Massy - Verrières       47940        Massy - Verrières  ...
# 169        Massy - Verrières       47940        Massy - Verrières  ...
# 176                   Juvisy       45739                   Juvisy  ...
# 177                   Juvisy       45739                   Juvisy  ...
#
#     ind_25_39 ind_40_54 ind_55_64 ind_65_79 ind_80p ind_inc pre_IDF select  \
# 4      8501.5    6004.0    2991.0    2856.0   863.0    20.0     1.0    1.0
# 5      8501.5    6004.0    2991.0    2856.0   863.0    20.0     1.0    1.0
# 6      8501.5    6004.0    2991.0    2856.0   863.0    20.0     1.0    1.0
# 14     3106.0    1273.0     404.0     300.0    94.1    20.0     1.0    1.0
# 15     3106.0    1273.0     404.0     300.0    94.1    20.0     1.0    1.0
# 19     8465.5    5728.5    3116.0    2783.0   803.0   167.0     1.0    1.0
# 20     8465.5    5728.5    3116.0    2783.0   803.0   167.0     1.0    1.0
# 21     8465.5    5728.5    3116.0    2783.0   803.0   167.0     1.0    1.0
# 47     1894.4    1595.4    1062.1     864.0   266.0    28.0     1.0    1.0
# 48     1894.4    1595.4    1062.1     864.0   266.0    28.0     1.0    1.0
# 58     1241.0    1383.0     785.0     779.0   238.0    29.0     1.0    1.0
# 59     1241.0    1383.0     785.0     779.0   238.0    29.0     1.0    1.0
# 66     3148.1    2449.0    1398.0    1468.9   563.0     6.0     1.0    1.0
# 67     3148.1    2449.0    1398.0    1468.9   563.0     6.0     1.0    1.0
# 168    1388.0    1102.5     642.0     530.0   245.0     7.0     1.0    1.0
# 169    1388.0    1102.5     642.0     530.0   245.0     7.0     1.0    1.0
# 176    1707.4    1119.0     571.1     557.0   283.9     3.0     1.0    1.0
# 177    1707.4    1119.0     571.1     557.0   283.9     3.0     1.0    1.0
#
#     expt
# 4    1.0 NaN
# 5    1.0 NaN
# 6    1.0 NaN
# 14   1.0 NaN
# 15   1.0 NaN
# 19   1.0 NaN
# 20   1.0 NaN
# 21   1.0 NaN
# 47   1.0 NaN
# 48   1.0 NaN
# 58   1.0 NaN
# 59   1.0 NaN
# 66   1.0 NaN
# 67   1.0 NaN
# 168  1.0 NaN
# 169  1.0 NaN
# 176  1.0 NaN
# 177  1.0 NaN
#
# [18 rows x 64 columns]

# %% [markdown]
# Il y finallement 18 lignes pour 8 stations redondantes. On décide de completer la colonne *res_com* avec toutes les lignes en correspondance.

# %%
stations_RER.shape
# Out:
# (244, 64)

# %%
# Grouper les données par 'id_ref_ZdC' et appliquer une fonction personnalisée pour concaténer 'res_com'
def concatenate_res_com(group):
    # Concaténer toutes les 'res_com' avec un séparateur, par exemple une virgule ou un espace
    return ', '.join(group['res_com'])

# Appliquer la fonction personnalisée pour chaque groupe
aggregated_stations = stations_RER.groupby('id_ref_ZdC').apply(concatenate_res_com).reset_index(name='res_com')

# %%
aggregated_stations
# Out:
#      id_ref_ZdC              res_com
# 0         59420                RER D
# 1         59447                RER D
# 2         59470                RER D
# 3         59531                RER C
# 4         59565                RER D
# ..          ...                  ...
# 229      478505         RER C, RER D
# 230      478733  RER E, RER B, RER D
# 231      478855                RER C
# 232      478926                RER A
# 233      479919                RER A
#
# [234 rows x 2 columns]

# %%
unique_stations = stations_RER.drop_duplicates(subset='id_ref_ZdC').drop(columns=['res_com'])
final_stations = unique_stations.merge(aggregated_stations, on='id_ref_ZdC')

# %%
final_stations.shape
# Out:
# (234, 64)

# %% [markdown]
# Il y a bien 10 lignes de moins. On vérifie que l'opération a été faite correctement sur la station Gare du Nord.

# %%
final_stations[final_stations['nom_long']=='Magenta']
# Out:
#                                Geo Point  \
# 16  48.88077520385858, 2.358732959087859
#
#                                             Geo Shape  gares_id nom_long  \
# 16  {"coordinates": [2.358732959087859, 48.8807752...       490  Magenta
#
#    nom_so_gar nom_su_gar  id_ref_ZdC       nom_ZdC  id_ref_ZdA  nom_ZdA  ...  \
# 16        NaN        NaN      478733  Gare du Nord       58572  Magenta  ...
#
#    ind_40_54 ind_55_64 ind_65_79 ind_80p ind_inc pre_IDF select expt      \
# 16    5728.5    3116.0    2783.0   803.0   167.0     1.0    1.0  1.0 NaN
#
#                 res_com
# 16  RER E, RER B, RER D
#
# [1 rows x 64 columns]

# %%
final_stations[final_stations['nom_long']=='Magenta'].loc[:,['nom_long', 'res_com']]
# Out:
#    nom_long              res_com
# 16  Magenta  RER E, RER B, RER D

# %% [markdown]
# Pour une seule ligne on a bien accès à toutes les lignes. On vérifie qu'il n'y a plus de redondance pour être certain que la procédure a fonctionné correctement.

# %%
# Étape 1: Trouver les valeurs de 'id_ref_ZdC' qui apparaissent plus d'une fois.
duplicate_id_ref_ZdC = final_stations['id_ref_ZdC'].value_counts()
duplicate_id_ref_ZdC = duplicate_id_ref_ZdC[duplicate_id_ref_ZdC > 1].index

# Étape 2: Filtrer le DataFrame pour afficher seulement les lignes avec les valeurs répétées de 'id_ref_ZdC'
stations_RER_duplicates = final_stations[final_stations['id_ref_ZdC'].isin(duplicate_id_ref_ZdC)]
stations_RER_duplicates
# Out:
# Empty GeoDataFrame
# Columns: [Geo Point, Geo Shape, gares_id, nom_long, nom_so_gar, nom_su_gar, id_ref_ZdC, nom_ZdC, id_ref_ZdA, nom_ZdA, idrefliga, idrefligc, indice_lig, mode_, tertrain, terrer, termetro, tertram, terval, exploitant, idf, principal, x, y, picto ligne, nom_iv, geometry, index_right, idcar_1km, i_est_1km, lcog_geo, ind, men, men_pauv, men_1ind, men_5ind, men_prop, men_fmp, ind_snv, men_surf, men_coll, men_mais, log_av45, log_45_70, log_70_90, log_ap90, log_inc, log_soc, ind_0_3, ind_4_5, ind_6_10, ind_11_17, ind_18_24, ind_25_39, ind_40_54, ind_55_64, ind_65_79, ind_80p, ind_inc, pre_IDF, select, expt, , res_com]
# Index: []
#
# [0 rows x 64 columns]

# %%
final_stations.shape
# Out:
# (234, 64)

# %% [markdown]
# Tout est bon !
