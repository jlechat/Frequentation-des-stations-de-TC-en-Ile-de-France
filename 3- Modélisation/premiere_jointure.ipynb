# %% [markdown]
# # Première jointure entre la base validation et les stations INSEE
# Ce fichier a pour but de faire la jointure entre les données de validation et les stations de *RER* afin de voir s'il manque des stations pendant la jointure.
#
# ## Packages et importation des données

# %%
import pandas as pd
from pre_process_validations_stations import df_stations, df_validations

# %%
validations=df_validations()

# %%
stations=df_stations()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/mamba/share/proj failed

# %%
validations.head()
# Out:
#          JOUR    lda CATEGORIE_TITRE  NB_VALD
# 0  2023-01-01  59403       AMETHYSTE        5
# 1  2023-01-01  59403             FGT        5
# 2  2023-01-01  59403       IMAGINE R       17
# 3  2023-01-01  59403          NAVIGO       10
# 4  2023-01-01  59403             TST        5

# %%
stations.head()
# Out:
#                                Geo Point  \
# 0   48.53289010230884, 2.290082513840396
# 1  48.529746917640566, 2.572073662735742
# 2  48.725535303926115, 2.419565024387933
# 3  48.932196005027805, 2.495513142584313
# 4  48.79333629530144, 2.3222016336701206
#
#                                            Geo Shape  gares_id  \
# 0  {"coordinates": [2.290082513840396, 48.5328901...       101
# 1  {"coordinates": [2.572073662735742, 48.5297469...        85
# 2  {"coordinates": [2.419565024387933, 48.7255353...         3
# 3  {"coordinates": [2.495513142584313, 48.9321960...        37
# 4  {"coordinates": [2.322201633670121, 48.7933362...        45
#
#            nom_long nom_so_gar nom_su_gar  id_ref_ZdC           nom_ZdC  \
# 0            Bouray        NaN        NaN       59830            Bouray
# 1   Boissise-le-Roi        NaN        NaN       61943   Boissise-le-Roi
# 2             Ablon        NaN        NaN       69554             Ablon
# 3  Aulnay-sous-Bois        NaN        NaN       72646  Aulnay-sous-Bois
# 4           Bagneux        NaN        NaN       70210           Bagneux
#
#    id_ref_ZdA           nom_ZdA  ... ind_40_54 ind_55_64 ind_65_79 ind_80p  \
# 0       47905            Bouray  ...     138.0      87.0      83.0    46.0
# 1       45763   Boissise-le-Roi  ...     192.9     112.9     158.8    68.1
# 2       46387             Ablon  ...     865.0     445.0     462.1   201.0
# 3       43071  Aulnay-sous-Bois  ...    1154.0     690.0     593.0   238.0
# 4       44493           Bagneux  ...    2757.0    1675.0    1407.0   577.0
#
#   ind_inc pre_IDF select expt     res_com
# 0     1.0     1.0    1.0  1.0 NaN   RER C
# 1     1.0     1.0    1.0  1.0 NaN   RER D
# 2     1.0     1.0    1.0  1.0 NaN   RER C
# 3     3.0     1.0    1.0  1.0 NaN   RER B
# 4    21.0     1.0    1.0  1.0 NaN   RER B
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Identification des lignes avec un problème de jointure

# %%
joint_table = pd.merge(validations, stations, left_on='lda', right_on='id_ref_ZdC', how='right')

# %%
joint_table.head()
# Out:
#          JOUR      lda CATEGORIE_TITRE  NB_VALD  \
# 0  2023-01-01  59830.0               ?      5.0
# 1  2023-01-01  59830.0       AMETHYSTE      5.0
# 2  2023-01-01  59830.0             FGT      5.0
# 3  2023-01-01  59830.0       IMAGINE R     82.0
# 4  2023-01-01  59830.0          NAVIGO    101.0
#
#                               Geo Point  \
# 0  48.53289010230884, 2.290082513840396
# 1  48.53289010230884, 2.290082513840396
# 2  48.53289010230884, 2.290082513840396
# 3  48.53289010230884, 2.290082513840396
# 4  48.53289010230884, 2.290082513840396
#
#                                            Geo Shape  gares_id nom_long  \
# 0  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
# 1  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
# 2  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
# 3  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
# 4  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
#
#   nom_so_gar nom_su_gar  ...  ind_40_54 ind_55_64  ind_65_79 ind_80p ind_inc  \
# 0        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
# 1        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
# 2        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
# 3        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
# 4        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
#
#   pre_IDF select expt     res_com
# 0     1.0    1.0  1.0 NaN   RER C
# 1     1.0    1.0  1.0 NaN   RER C
# 2     1.0    1.0  1.0 NaN   RER C
# 3     1.0    1.0  1.0 NaN   RER C
# 4     1.0    1.0  1.0 NaN   RER C
#
# [5 rows x 68 columns]

# %%
rows_with_lda_nan = joint_table[pd.isna(joint_table['lda'])]
rows_with_lda_nan
# Out:
#        JOUR  lda CATEGORIE_TITRE  NB_VALD  \
# 23505   NaN  NaN             NaN      NaN
# 69189   NaN  NaN             NaN      NaN
# 142215  NaN  NaN             NaN      NaN
# 151478  NaN  NaN             NaN      NaN
# 181727  NaN  NaN             NaN      NaN
# 225119  NaN  NaN             NaN      NaN
# 235122  NaN  NaN             NaN      NaN
#
#                                      Geo Point  \
# 23505     48.92087280342236, 2.313835382457718
# 69189     48.87215749394265, 2.329927170608275
# 142215   48.881759488218286, 2.357570193470876
# 151478   48.689567256029264, 2.383833358799738
# 181727  48.770778916124826, 2.6902527821957585
# 225119    48.84084437122463, 2.549900487641345
# 235122   48.43692393670402, 2.1595305875651536
#
#                                                 Geo Shape  gares_id  \
# 23505   {"coordinates": [2.313835382457718, 48.9208728...       450
# 69189   {"coordinates": [2.329927170608275, 48.8721574...        32
# 142215  {"coordinates": [2.357570193470876, 48.8817594...       309
# 151478  {"coordinates": [2.383833358799738, 48.6895672...       387
# 181727  {"coordinates": [2.690252782195758, 48.7707789...       965
# 225119  {"coordinates": [2.549900487641345, 48.8408443...       598
# 235122  {"coordinates": [2.159530587565154, 48.4369239...       271
#
#                          nom_long nom_so_gar nom_su_gar  ...  ind_40_54  \
# 23505              Les Grésillons        NaN        NaN  ...     1078.0
# 69189                       Auber        NaN        NaN  ...     1784.0
# 142215               Gare du Nord        NaN        NaN  ...     5728.5
# 151478                     Juvisy        NaN        NaN  ...     1119.0
# 181727          Ozoir-la-Ferrière        NaN        NaN  ...      432.0
# 225119  Noisy-le-Grand-Mont d'Est        NaN        NaN  ...     2278.0
# 235122                    Étampes        NaN        NaN  ...      723.0
#
#        ind_55_64  ind_65_79 ind_80p ind_inc pre_IDF select expt      \
# 23505      490.0      430.9   107.0    28.0     1.0    1.0  1.0 NaN
# 69189      940.0      866.0   290.0     1.0     1.0    1.0  1.0 NaN
# 142215    3116.0     2783.0   803.0   167.0     1.0    1.0  1.0 NaN
# 151478     571.1      557.0   283.9     3.0     1.0    1.0  1.0 NaN
# 181727     207.0      251.9    62.1     5.0     1.0    1.0  1.0 NaN
# 225119    1412.0     1152.0   340.0    52.0     1.0    1.0  1.0 NaN
# 235122     447.1      424.0   173.0     2.0     1.0    1.0  1.0 NaN
#
#                     res_com
# 23505                 RER C
# 69189                 RER A
# 142215  RER B, RER D, RER E
# 151478         RER D, RER C
# 181727                RER E
# 225119                RER A
# 235122                RER C
#
# [7 rows x 68 columns]

# %% [markdown]
# ## Résolution de l'erreur

# %% [markdown]
# Il faut donc régler cette erreur d'association (qui vient probablement de changements dans la base qui n'ont pas été répercuté).

# %%
stations.loc[stations['id_ref_ZdC'] == 72225, 'id_ref_ZdC'] = 72219
stations.loc[stations['id_ref_ZdC'] == 478926, 'id_ref_ZdC'] = 73792
stations.loc[stations['id_ref_ZdC'] == 478733, 'id_ref_ZdC'] = 71410
stations.loc[stations['id_ref_ZdC'] == 478505, 'id_ref_ZdC'] = 62737
stations.loc[stations['id_ref_ZdC'] == 462934, 'id_ref_ZdC'] = 67747
stations.loc[stations['id_ref_ZdC'] == 479919, 'id_ref_ZdC'] = 412697
stations.loc[stations['id_ref_ZdC'] == 478855, 'id_ref_ZdC'] = 59577

# %%
stations[stations['nom_long']=="Étampes"]
# Out:
#                                  Geo Point  \
# 173  48.43692393670402, 2.1595305875651536
#
#                                              Geo Shape  gares_id nom_long  \
# 173  {"coordinates": [2.159530587565154, 48.4369239...       271  Étampes
#
#     nom_so_gar nom_su_gar  id_ref_ZdC nom_ZdC  id_ref_ZdA  nom_ZdA  ...  \
# 173        NaN        NaN      478855  Étampe       43080  Étampes  ...
#
#     ind_40_54 ind_55_64 ind_65_79 ind_80p ind_inc pre_IDF select expt      \
# 173     723.0     447.1     424.0   173.0     2.0     1.0    1.0  1.0 NaN
#
#     res_com
# 173   RER C
#
# [1 rows x 64 columns]

# %%
joint_table = pd.merge(validations, stations, left_on='lda', right_on='id_ref_ZdC', how='right')
rows_with_lda_nan = joint_table[pd.isna(joint_table['lda'])]
rows_with_lda_nan
# Out:
# Empty DataFrame
# Columns: [JOUR, lda, CATEGORIE_TITRE, NB_VALD, Geo Point, Geo Shape, gares_id, nom_long, nom_so_gar, nom_su_gar, id_ref_ZdC, nom_ZdC, id_ref_ZdA, nom_ZdA, idrefliga, idrefligc, indice_lig, mode_, tertrain, terrer, termetro, tertram, terval, exploitant, idf, principal, x, y, picto ligne, nom_iv, geometry, index_right, idcar_1km, i_est_1km, lcog_geo, ind, men, men_pauv, men_1ind, men_5ind, men_prop, men_fmp, ind_snv, men_surf, men_coll, men_mais, log_av45, log_45_70, log_70_90, log_ap90, log_inc, log_soc, ind_0_3, ind_4_5, ind_6_10, ind_11_17, ind_18_24, ind_25_39, ind_40_54, ind_55_64, ind_65_79, ind_80p, ind_inc, pre_IDF, select, expt, , res_com]
# Index: []
#
# [0 rows x 68 columns]

# %%
joint_table.head()
# Out:
#          JOUR    lda CATEGORIE_TITRE  NB_VALD  \
# 0  2023-01-01  59830               ?        5
# 1  2023-01-01  59830       AMETHYSTE        5
# 2  2023-01-01  59830             FGT        5
# 3  2023-01-01  59830       IMAGINE R       82
# 4  2023-01-01  59830          NAVIGO      101
#
#                               Geo Point  \
# 0  48.53289010230884, 2.290082513840396
# 1  48.53289010230884, 2.290082513840396
# 2  48.53289010230884, 2.290082513840396
# 3  48.53289010230884, 2.290082513840396
# 4  48.53289010230884, 2.290082513840396
#
#                                            Geo Shape  gares_id nom_long  \
# 0  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
# 1  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
# 2  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
# 3  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
# 4  {"coordinates": [2.290082513840396, 48.5328901...       101   Bouray
#
#   nom_so_gar nom_su_gar  ...  ind_40_54 ind_55_64  ind_65_79 ind_80p ind_inc  \
# 0        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
# 1        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
# 2        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
# 3        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
# 4        NaN        NaN  ...      138.0      87.0       83.0    46.0     1.0
#
#   pre_IDF select expt     res_com
# 0     1.0    1.0  1.0 NaN   RER C
# 1     1.0    1.0  1.0 NaN   RER C
# 2     1.0    1.0  1.0 NaN   RER C
# 3     1.0    1.0  1.0 NaN   RER C
# 4     1.0    1.0  1.0 NaN   RER C
#
# [5 rows x 68 columns]
